# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# X axis
X = [1,2,3,4,5]
# Y axis 
Y = [100,200,300,400,500]

# %%
# Plot function (Which create a line plot)
plt.plot(X,Y)

# Show function (To see the plot)
plt.show()

# %%
# Real Data
oscar_movies = [
    "Bhaag Milkha Bhaag",
    "3 idiots",
    "12th fail",
    "Zindagi Na Milegi Dobara",
    "Shershaah"
]
years = [2012,2013,2014,2015,2016]
oscar_revenue = [100,200,300,400,500]

plt.plot(years,oscar_revenue)

# To give title to the plot
plt.title("Oscar movies revenue in each year")

# X-axis label
plt.xlabel("Years")

# Y-axis label
plt.ylabel("revenue (in crores)")
# Out:
# Text(0, 0.5, 'revenue (in crores)')

# %%
# Multiple data plots
non_oscar_movies = [
    "Bajrangi Bhaijaan",
    "Pritam And Pedro",
    "Stree",
    "Sector 36",
    "Housefull"
]

non_oscar_revenue = [800,600,50,70,100]

plt.plot(years,oscar_revenue , label = "oscar movies")
plt.plot(years,non_oscar_revenue , label = "non-oscar movies")

plt.title("Oscar vs non-oscar Movies")
plt.xlabel("years")
plt.ylabel("revenue (in crores)")
# To show the plot label
plt.legend()
# Can specify position of the lable box
plt.legend(loc = "upper left")

# %%
# Format strings : A format string consists of a part for color, marker and line
plt.plot(years,oscar_revenue ,"o:r",label = "oscar movies")
plt.plot(years,non_oscar_revenue ,",--b", label = "non-oscar movies")

plt.title("Oscar vs non-oscar Movies")
plt.xlabel("years")
plt.ylabel("revenue (in crores)")
plt.legend()

# can give seprate values

plt.plot(years,oscar_revenue ,color = "green" ,marker = "s",linestyle="-",linewidth = "5",label = "oscar movies")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Format strings : A format string consists of a part for color, marker and line
# ----> 2 plt.plot(years,oscar_revenue ,"o:r",label = "oscar movies")
#       3 plt.plot(years,non_oscar_revenue ,",--b", label = "non-oscar movies")
#       5 plt.title("Oscar vs non-oscar Movies")
#
# NameError: name 'plt' is not defined

# %%
# Other Methods and Attributes
oscar_movies = [
    "Bhaag Milkha Bhaag",
    "3 idiots",
    "12th fail",
    "Zindagi Na Milegi Dobara",
    "Shershaah"
]
oscar_revenue = [100,200,300,400,500]
plt.plot(oscar_movies,oscar_revenue,label = "oscar movies")

plt.title("Oscar movies revenue")
plt.xlabel("oscar movies")
plt.ylabel("revenue (in crores)")
plt.legend()


# To check available styles 
print(plt.style.available)

# To set a particular available style
plt.style.use("dark_background")

# To set it back to default
plt.style.use("default")

# To create a grid in graph
plt.grid()

# To get a tight layout (giving extra spacing and tight allignment of labels)
plt.tight_layout()

# To save a plot as png
plt.savefig("final_plot.png")
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Bar Graph (This creates a vertical bar graph where x-axis = categories y-axis = values)
years = [2012,2013,2014,2015,2016]
oscar_revenue = [100,200,300,400,500]

plt.bar(years,oscar_revenue)
plt.title("Oscar movies revenue each year")
plt.xlabel("years")
plt.ylabel("revenue (in crores)")

# To give bar labels (text above the bar)
# plt.text( x-axis alignment, y-axis alignment, text to display, alignment)

# For individual cell
plt.text(years[0],oscar_revenue[0] + 10,oscar_revenue[0],ha = "center")

# For all cells
for i in range(len(years)):
    plt.text(years[i],oscar_revenue[i] + 10,oscar_revenue[i],ha = "center")


# To increase x axis limit
plt.xlim()

# To increase y axis limit
plt.ylim(0,max(oscar_revenue)+100)
# Out:
# (0.0, 600.0)

# %%
# Multiple bar garphs
years = [2012,2013,2014,2015,2016]
oscar_revenue = [100,200,300,400,500]
non_oscar_revenue = [800,600,50,70,100]

x = np.arange(len(years))
width = 0.35

plt.bar(x-width/2  , oscar_revenue , width , label = "oscar movies")
plt.bar(x+width/2  , non_oscar_revenue , width , label = "non-oscar movies")
plt.title("Oscar movies revenue each year")
plt.xlabel("years")
plt.ylabel("revenue (in crores)")
plt.legend()

# To replace index value with the required values 
plt.xticks(x,years)
# Out:
# ([<matplotlib.axis.XTick at 0x1d8af175bd0>,
# ...
#  [Text(0, 0, '2012'),
#   Text(1, 0, '2013'),
#   Text(2, 0, '2014'),
#   Text(3, 0, '2015'),
#   Text(4, 0, '2016')])

# %%
# Horizontal bar chart (first pass y axis - categories and then pass x axis - values)
oscar_movies = [
    "Bhaag Milkha Bhaag",
    "3 idiots",
    "12th fail",
    "Zindagi Na Milegi Dobara",
    "Shershaah"
]
oscar_revenue = [100,200,300,400,500]
plt.barh(oscar_movies,oscar_revenue)
plt.title("Oscar movies revenue")
plt.xlabel("oscar movies")
plt.ylabel("revenue (in crores)")
# Out:
# Text(0, 0.5, 'revenue (in crores)')

# %%
# Scatter Plots

people = [
    "Person A", "Person B", "Person C", "Person D", "Person E",
    "Person F", "Person G", "Person H", "Person I", "Person J"
]

age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

plt.scatter(age,bp)
plt.title("Age vs Bp")
plt.xlabel("Age")
plt.ylabel("Bp")
plt.grid()

# Properties 

# Colors , size , marker , Transparency ,  
color = ["green" if x < 120 else "red" for x in bp]
plt.scatter(age,bp,color = color, s = bp , marker = "s",alpha = 0.8) 

# color map with range
plt.scatter(age,bp,s=bp,cmap= "OrRd",c=bp)


# To know the scale of color bar
plt.colorbar(label = "BP")

# %%
# Add Annotations
people = [
    "Person A", "Person B", "Person C", "Person D", "Person E",
    "Person F", "Person G", "Person H", "Person I", "Person J"
]

age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

plt.scatter(age,bp)
plt.title("Age vs Bp")
plt.xlabel("Age")
plt.ylabel("Bp")
plt.grid()

for i in range(len(people)):
    # annotate(what u want as text , on which (x,y) point , allignment of text (x,y))
    plt.annotate(people[i],xy = (age[i],bp[i]),xytext = (age[i],bp[i]+1) )

plt.xlim(min(age),max(age)+10)
plt.ylim(100,max(bp)+10)
# Out:
# (100.0, 160.0)

# %%
# Multiple plots 

cities = [
    "Delhi", "Mumbai", "Chennai", "Kolkata", "Bengaluru",
    "Hyderabad", "Jaipur", "Lucknow", "Pune", "Ahmedabad"
]

summer_temp = [42, 33, 38, 36, 31, 39, 41, 40, 34, 43]      # °C
summer_humidity = [30, 75, 70, 68, 55, 45, 25, 40, 60, 28]  # %


winter_temp = [7, 20, 24, 16, 16, 18, 9, 8, 15, 13]         # °C
winter_humidity = [60, 68, 72, 65, 58, 52, 50, 65, 55, 48]  # %

plt.scatter(summer_temp , summer_humidity , label = "summer")
plt.scatter(winter_temp , winter_humidity , label = "winter")
plt.legend()
plt.title("Summer vs Winter temperature and humidity")
plt.xlabel("Temperature (in *C)")
plt.ylabel("Humidity (in %)")
# Out:
# Text(0, 0.5, 'Humidity (in %)')

# %%
# Pie charts and customization of pie charts

Software_names = ["Windows","IOS","Linux"]
users = [1000,200,50]
colors = ["lightblue","grey","yellow"]
explode_values = [0.1,0,0]

plt.pie(users , labels = Software_names,
        autopct ="%1.1f%%", # Give percentage of each part
        colors = colors,    # To give custom colors to the pie chart
        wedgeprops = {      # To give properties to a specific edge
            "edgecolor" : "black",
            "linewidth" : 2,
            "linestyle" : "--",
            "alpha" : 0.9,
            # "fill" : False  # To remove colors
        },
        explode = explode_values, # To specifically standout any cell
        startangle = 90 , # To rotate the pie chart at a specific angle
        shadow = True # To add shadow (3D) effect
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1d8b5645bd0>,
# ...
#  [Text(-0.7053425396100119, -0.9708202211617241, 'Windows'),
#   Text(0.7530021742775245, 0.8018651542081878, 'IOS'),
#   Text(0.13786676454722313, 1.0913261452165803, 'Linux')],
#  [Text(-0.4114498147725069, -0.5663117956776724, '80.0%'),
#   Text(0.4107284586968315, 0.43738099320446605, '16.0%'),
#   Text(0.07520005338939444, 0.595268806481771, '4.0%')])

# %%
# Histogram (shows the distribution of numerical data divided into bins(ranges) and counting how many values fall into each bin)
np.random.seed(0)
scores = np.random.normal(70,10,100)

# To define ranges (0-30 , 30-50 , 50-70 , 70-90 , 90-100) => Where left value is inclusive and right value is exclusive
bins = [0,30,50,70,90,100]

plt.hist(scores , color = "skyblue" , edgecolor = "black",bins = bins, label = "students")

plt.title("Distrition of marks for students")
plt.xlabel("scores")
plt.ylabel("no. of students")
plt.legend()

# axv line (Axis Vertical line) => It is used to draw a vertical reference line at a specific x-value on a plot.
plt.axvline(
    x = 33,
    label = "passing marks (33)",
    color = "red",
    linewidth = 2,
    linestyle = "--"
)

# %%
# Multiple datasets

legit_transactions = [
    2.99, 5.49, 8.99, 12.50, 14.99, 19.99, 23.45, 29.99, 34.99, 39.50,
    45.00, 49.99, 55.25, 60.00, 75.99, 89.99, 120.50, 150.00, 199.99,
    249.99, 300.75, 450.00, 600.00, 850.00, 1200.00
]

fraud_transactions = [
    50, 100, 150, 200, 300, 500, 500, 750, 1000, 1000,
    1200, 1500, 1500, 2000, 2500, 3000, 3000
]

plt.hist(legit_transactions, color = "green" , edgecolor = "black", label = "legit", alpha = 0.5)
plt.hist(fraud_transactions, color = "red" , edgecolor = "black" , label = "fraud" , alpha = 0.5)

plt.title("Legit vs Fraud Transaction")
plt.xlabel("Amount (in $)")
plt.ylabel("No. of Transaction")
plt.legend()

# %%
# Box plot 
data = [7,8,5,6,9,4,10,12,15,-5,20]

plt.boxplot(data)
plt.grid(True)

# %%
# Multiple datasets , Horizontal box plot , show mean and change whisker length
group_1 = np.random.normal(50,10,100)
group_2 = np.random.normal(60,20,100)

plt.boxplot([group_1,group_2],vert = False , showmeans = True , whis = 2)
plt.grid(True)

# %%
# Stack plot

days = ["mon","tues","wed","thus","fri","sat","sun"]

direct = [20,40,60,80,100,120,140]
organic = [30,50,70,90,110,130,150]
social = [40,60,80,100,120,140,160]

plt.stackplot(days , direct , organic , social , labels = ["Direct","Organic","social"])

plt.title("Days plot between direct ,organic ,and social")
plt.xlabel("Days")
plt.ylabel("No. of sales")
plt.legend()

# %%
# Subplots - Creating multiple plots into single plot

x = [1,2,3,4,5,6,7,8]
y1 = [np.sqrt(i) for i in x] # Square root
y2 = [i*2 for i in x] # Double
y3 = [i**2 for i in x] # Square
y4 = [i**3 for i in x] # Cube


plt.subplot(2,2,1)
plt.plot(x,y1)
plt.title("x vs square root of x")


plt.subplot(2,2,2)
plt.plot(x,y2)
plt.title("x vs double of x")

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title("x vs square of x")

plt.subplot(2,2,4)
plt.plot(x,y4)
plt.title("x vs cube of x")

plt.tight_layout()

# %%
# Modern matplot (Object Oriented API)

fig , ax = plt.subplots(2,2)

ax[0][0].plot(x,y1)

ax[0][1].plot(x,y2)

ax[1][0].plot(x,y3)

ax[1][1].plot(x,y4)


fig.suptitle("Multiple plots")
fig.tight_layout()

# %%
# Weekly Temperature (Practice problem)
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

cities = ["New York", "London", "Delhi", "Tokyo"]

temperatures = [
    [22, 23, 21, 24, 25],  # New York
    [18, 19, 17, 20, 21],  # London
    [30, 32, 31, 33, 34],  # Delhi
    [25, 26, 24, 27, 28]   # Tokyo
]

fig , ax = plt.subplots(2,2)

# ax[0][0].plot(days,temperatures[0])
# ax[0][1].plot(days,temperatures[1])
# ax[1][0].plot(days,temperatures[2])
# ax[1][1].plot(days,temperatures[3])

for i in range(2):
    for j in range(2):
        ax[i][j].plot(days,temperatures[i])
