# %% [markdown]
# # DIMENSIONALITY REDUCTION

# %%
from sklearn.datasets import load_iris
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
iris = load_iris()

# %%
X = pd.DataFrame(iris.data)
y = pd.DataFrame(iris.target)

# %%
# Scaling Data in PCA is very important
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# As we want to convert 4 features into 2 features
pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X_scaled)

# %%
# Variance Ratio
print(f"Variance ratio : {pca.explained_variance_ratio_}")
# Out:
# Variance ratio : [0.72962445 0.22850762]

# %%
# To know the components (Eigen Values)
print(pca.components_)
# Out:
# [[ 0.52106591 -0.26934744  0.5804131   0.56485654]
#  [ 0.37741762  0.92329566  0.02449161  0.06694199]]
